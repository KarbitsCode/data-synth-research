# %%
import sys
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Get the project root directory (parent of notebooks folder)
project_root = os.path.dirname(os.getcwd())
sys.path.insert(0, project_root)

# %%
data_path = os.path.join(project_root, 'results', 'xgb_imbalanced_handling_results.csv')
df = pd.read_csv(data_path)
df
# Out:
#                           Model    PR-AUC  Recall@Prec>=90%  Recall@Prec>=95%  \
# 0                  Baseline XGB  0.787433          0.733333          0.653333
# 1                XGB with SMOTE  0.764462          0.733333          0.666667
# 2     XGB with Borderline SMOTE  0.778845          0.760000          0.613333
# 3             XGB with SMOTEENN  0.768925          0.746667          0.666667
# 4          XGB with Pytorch GAN  0.759596          0.560000          0.546667
# 5                XGB with CTGAN  0.627065          0.053333          0.053333
# 6  XGB with Conditional WGAN-GP  0.761734          0.720000          0.640000
# 7            XGB with SDV CTGAN  0.786290          0.693333          0.640000
# 8       XGB with SDV Copula GAN  0.768150          0.746667          0.640000
#
#    Recall@5%FPR  Lift@Top-1%   FPR@0.5  F1-Score  Precision    Recall
# 0      0.880000    85.426315  0.000211  0.791667   0.826087  0.760000
# 1      0.853333    80.087170  0.010952  0.163158   0.090511  0.826667
# 2      0.853333    84.091529  0.000879  0.641304   0.541284  0.786667
# 3      0.853333    81.421957  0.011602  0.153266   0.084605  0.813333
# 4      0.880000    85.426315  0.005906  0.258475   0.153652  0.813333
# 5      0.880000    86.761101  0.000563  0.703030   0.644444  0.773333
# 6      0.880000    82.756743  0.007910  0.211244   0.121094  0.826667
# 7      0.893333    85.426315  0.001107  0.613065   0.491935  0.813333
# 8      0.853333    82.756743  0.001178  0.600985   0.476562  0.813333
